# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamadreza1368/Diabetic_Retinopathy/blob/main/Text_from_image_using_EasyOCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import cv2
from PIL import Image, ImageDraw

# %%
image_path = "/content/Gjvv2viXcAAly5h.jpg"
image = cv2.imread(image_path)

# %%
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# # EasyOCR method

# %%
# !pip install easyocr -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 40.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 67.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 48.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 29.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 41.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.9/292.9 kB 22.5 MB/s eta 0:00:00

# %%
import easyocr

reader = easyocr.Reader(['fa','fa'], gpu=False)
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.

# %%
results = reader.readtext(np.array(image))

# %%
results
# Out:
# [[[[np.int32(34), 0],
#    [np.int32(218), 0],
#    [np.int32(218), np.int32(30)],
#    [np.int32(34), np.int32(30)]],
#   '٤٢٦٧،٧٠]٧',
#   np.float64(0.1007867640462414)],
#  [[[np.int32(226), 0],
#    [np.int32(258), 0],
#    [np.int32(258), np.int32(24)],
#    [np.int32(226), np.int32(24)]],
#   ':',
#   np.float64(0.9453239276693957)],
#  [[[np.int32(270), 0],
#    [np.int32(294), 0],
#    [np.int32(294), np.int32(24)],
#    [np.int32(270), np.int32(24)]],
#   '4',
#   np.float64(0.9981916980507322)],
#  [[[np.int32(341), 0],
#    [np.int32(405), 0],
#    [np.int32(405), np.int32(37)],
#    [np.int32(341), np.int32(37)]],
#   '؟39',
#   np.float64(0.07798482346524435)],
#  [[[np.int32(41), np.int32(21)],
#    [np.int32(83), np.int32(21)],
#    [np.int32(83), np.int32(39)],
#    [np.int32(41), np.int32(39)]],
#   'ارسال',
#   np.float64(0.5840777578941885)],
#  [[[np.int32(111), np.int32(19)],
#    [np.int32(223), np.int32(19)],
#    [np.int32(223), np.int32(35)],
#    [np.int32(111), np.int32(35)]],
#   'كد خر : ٨٣١٧٣',
#   np.float64(0.42193112912651054)],
#  [[[np.int32(345), np.int32(23)],
#    [np.int32(389), np.int32(23)],
#    [np.int32(389), np.int32(39)],
#    [np.int32(345), np.int32(39)]],
#   'ه9م',
#   np.float64(0.04402827748957751)],
#  [[[np.int32(427), np.int32(21)],
#    [np.int32(487), np.int32(21)],
#    [np.int32(487), np.int32(35)],
#    [np.int32(427), np.int32(35)]],
#   'دالس',
#   np.float64(0.22264118336305946)],
#  [[[np.int32(34), np.int32(96)],
#    [np.int32(415), np.int32(96)],
#    [np.int32(415), np.int32(141)],
#    [np.int32(34), np.int32(141)]],
#   'dawgi Ciiy Jll oJy :clo',
#   np.float64(0.6984515073389823)],
#  [[[np.int32(39), np.int32(133)],
#    [np.int32(299), np.int32(133)],
#    [np.int32(299), np.int32(173)],
#    [np.int32(39), np.int32(173)]],
#   'ايران فريفته توسعه',
#   np.float64(0.871989289487435)],
#  [[[np.int32(364), np.int32(130)],
#    [np.int32(492), np.int32(130)],
#    [np.int32(492), np.int32(172)],
#    [np.int32(364), np.int32(172)]],
#   'میرباقری :',
#   np.float64(0.891829222756213)],
#  [[[np.int32(19), np.int32(170)],
#    [np.int32(114), np.int32(170)],
#    [np.int32(114), np.int32(211)],
#    [np.int32(19), np.int32(211)]],
#   'dawg',
#   np.float64(0.5682295408778573)],
#  [[[np.int32(225), np.int32(168)],
#    [np.int32(329), np.int32(168)],
#    [np.int32(329), np.int32(206)],
#    [np.int32(225), np.int32(206)]],
#   '9J0-',
#   np.float64(0.11025684326887131)],
#  [[[np.int32(352), np.int32(176)],
#    [np.int32(412), np.int32(176)],
#    [np.int32(412), np.int32(208)],
#    [np.int32(352), np.int32(208)]],
#   '38',
#   np.float64(0.17037849227964072)],
#  [[[np.int32(25), np.int32(195)],
#    [np.int32(493), np.int32(195)],
#    [np.int32(493), np.int32(237)],
#    [np.int32(25), np.int32(237)]],
#   'نمى شوند : در قطرا ء ترکیه هم توسعه',
#   np.float64(0.2290209911029603)],
#  [[[np.int32(370), np.int32(236)],
#    [np.int32(470), np.int32(236)],
#    [np.int32(470), np.int32(266)],
#    [np.int32(370), np.int32(266)]],
#   '031=2',
#   np.float64(0.7068360917111296)],
#  [[[np.int32(373), np.int32(263)],
#    [np.int32(495), np.int32(263)],
#    [np.int32(495), np.int32(303)],
#    [np.int32(373), np.int32(303)]],
#   'رخ نداده',
#   np.float64(0.6178018349738583)],
#  [[[np.float64(295.56408368276453), np.float64(136.26661757518775)],
#    [np.float64(365.36118659289696), np.float64(130.83149252071163)],
#    [np.float64(367.43591631723547), np.float64(169.73338242481225)],
#    [np.float64(296.63881340710304), np.float64(175.16850747928837)]],
#   'مردم',
#   np.float64(0.999903678894043)]]

# %%
img_df = pd.DataFrame(results, columns=['bbox','text','prediction_conf'])

# %%
img_df.head(10)
# Out:
#                                              bbox                     text  \
# 0        [[34, 0], [218, 0], [218, 30], [34, 30]]                ٤٢٦٧،٧٠]٧
# 1      [[226, 0], [258, 0], [258, 24], [226, 24]]                        :
# 2      [[270, 0], [294, 0], [294, 24], [270, 24]]                        4
# 3      [[341, 0], [405, 0], [405, 37], [341, 37]]                      ؟39
# 4        [[41, 21], [83, 21], [83, 39], [41, 39]]                    ارسال
# 5    [[111, 19], [223, 19], [223, 35], [111, 35]]            كد خر : ٨٣١٧٣
# 6    [[345, 23], [389, 23], [389, 39], [345, 39]]                      ه9م
# 7    [[427, 21], [487, 21], [487, 35], [427, 35]]                     دالس
# 8    [[34, 96], [415, 96], [415, 141], [34, 141]]  dawgi Ciiy Jll oJy :clo
# 9  [[39, 133], [299, 133], [299, 173], [39, 173]]       ايران فريفته توسعه
#
#    prediction_conf
# 0         0.100787
# 1         0.945324
# 2         0.998192
# 3         0.077985
# 4         0.584078
# 5         0.421931
# 6         0.044028
# 7         0.222641
# 8         0.698452
# 9         0.871989

# %%
img_df['text']
# Out:
# 0                               ٤٢٦٧،٧٠]٧
# 1                                       :
# 2                                       4
# 3                                     ؟39
# 4                                   ارسال
# 5                           كد خر : ٨٣١٧٣
# 6                                     ه9م
# 7                                    دالس
# 8                 dawgi Ciiy Jll oJy :clo
# 9                      ايران فريفته توسعه
# 10                             میرباقری :
# 11                                   dawg
# 12                                   9J0-
# 13                                     38
# 14    نمى شوند : در قطرا ء ترکیه هم توسعه
# 15                                  031=2
# 16                               رخ نداده
# 17                                   مردم
# Name: text, dtype: object

# %%
top_left = tuple(results[0][0][0])
bottom_right = tuple(results[0][0][2])

text = results[0][1]

font = cv2.FONT_HERSHEY_COMPLEX

# %%
img = cv2.rectangle(image, top_left,bottom_right,(0,255,0),5)
img = cv2.putText(img, text, top_left, font, 1, (125,29,241),2,cv2.LINE_AA)

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
for detection in results:
    top_left = tuple([int(val)for val in detection[0][0]])
    bottom_right = tuple([int(val)for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_COMPLEX

    text_size = cv2.getTextSize(text, font, 1, 2)[0]
    text_position = (top_left[0] + 10, top_left[1] + text_size[1] + 10)  # Adjust the position as needed

    image = cv2.rectangle(image, top_left,bottom_right,(0,255,0),5)
    image = cv2.putText(image, text, top_left, font,1,(125,29,241),2,cv2.LINE_AA)

plt.figure(figsize=(10,10))
plt.imshow(image)
plt.axis('off')
plt.show()
